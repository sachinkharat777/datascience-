# %%
# a=10
# b =20
# a+b
# Out:
# 30

# %%
print("sachin")
# Out:
# sachin

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\sachi\\OneDrive\\Documents\\NareshIT\\Python_sessions'

# %%
a=10
b=20
c=a+b
print(c)
# Out:
# 30
