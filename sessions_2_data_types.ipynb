# %%
# write a program , take salary and tax and find tax_amount?

salary= 100000
tax_percentage =10
tax_amount= (salary*tax_percentage)/100
tax_amount
# Out:
# 10000.0

# %% [markdown]
# - int
# - float
# - complex
# - str
# - list
# - tuple
# - dict
# - set
# - frozenset
# - range
# - bytes
# - bytearray
# - memoryview

# %% [markdown]
# **integer data type**

# %%
number= 100
type(number)
# Out:
# int

# %% [markdown]
# **float data type**

# %%
n1=10.5
type(n1)
# Out:
# float

# %% [markdown]
# **Exponential Represention**

# %%
print(1e1)    # 1* 10
print(1e1)   # 1* 10^1
print(1e2)  # 1* 10^2 ===> 1*100
print(2e3)  #2*1000 ---
# Out:
# 10.0
# 100.0
# 2000.0

# %%
print(1e1, 1e+1)  # 1*10
print(1e2, 1e+2)  # 1*100
print(2e3,2e+3)  # 1*1000
# Out:
# 10.0 10.0
# 100.0 100.0
# 2000.0 2000.0

# %%
1e+1  # 1*10
1e-1  #1/10
# Out:
# 0.1

# %%
2e+3  #2*1000 --> 2*
2e-3  #2*1000
# Out:
# 0.002

# %% [markdown]
# **String**

# %%
#varible
#keyword
#string

name="naresh it"
institute_name= "naresh it"
coaching_center="naresh it"

# %%
print(name)
name
# Out:
# naresh it
# 'naresh it'

# %%
print(institute_name)
institute_name
# Out:
# naresh it
# 'naresh it'

# %%
print(coaching_center)
coaching_center
# Out:
# naresh it
# 'naresh it'

# %%
greet1='naresh it'
greet2= '     naresh it'
len(greet1),len(greet2)
# Out:
# (9, 14)

# %%
print(greet1)
print(greet2)
# Out:
# naresh it
#      naresh it

# %%
greet1,greet2
# Out:
# ('naresh it', '     naresh it')

# %% [markdown]
# **Double quotes**

# %%
# single and double qoutes both are same 
name1= "hydrabad"
name1
# Out:
# 'hydrabad'

# %%
s1="I joined in Ds and AI class"  #works
s2="I joined in 'Ds and AI' class"  #works
s3='I joined in "Ds and AI" class'  #works
s4=I joined in "Ds and AI" class  # fail
s5= I joind in 'DS and AI' class  #fail
# Out:
# 'I joined in Ds and AI class'

# %%
print(s1)
s1
# Out:
# I joined in Ds and AI class
# 'I joined in Ds and AI class'

# %%
print(s2)
s2
# Out:
# I joined in 'Ds and AI' class
# "I joined in 'Ds and AI' class"

# %%
print(s3)
s3
# Out:
# I joined in "Ds and AI" class
# 'I joined in "Ds and AI" class'

# %%
print(s4)
s4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 print(s4)
#       2 s4
#
# NameError: name 's4' is not defined

# %% [markdown]
# **Triple quoutes**
#
# - in jupuyter notebook we have a **markdown**  option to write a information
#
# - **markdwom** means we are convying same information to the user
#
# - but in other platforms like **vscode PyCharm** we dont have markdown option
#
# - this is also calld as **Doc stirng**
#
# - the code part we can provide single or double quotes
#
# - but conveying the information about the code is **triple quotes**
# - **Triple quotes** are using in prompt engineering

# %% [markdown]
# **Boolean**
#
# - when we ask the questions to machine
# - machine always provide only two asnswers
#
#     - true
#     - false
#
# - true means 1
# - false means 0
#
# - you can think in another way true mean ON false means OFF

# %%
on = True
type(on)
# Out:
# bool

# %%
off= False
type(off)
# Out:
# bool

# %%
'True'=true
# Out:
#   Cell In[54], line 1
#     'True'=true
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
'true'=True
# Out:
#   Cell In[55], line 1
#     'true'=True
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?
