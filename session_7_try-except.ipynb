# %% [markdown]
# **try-except**
#
# - try except is used to handle the exeption mechenism
#
# - try except is used to catch and handle the errors
#
# - when we get the error python will stop the executon
#
# - using try except eventhough we get the errors, the execution will not stop
#
# - it will catch all the logical errors automatically
#
# - the actual code block will write in **try block**
#
# - if any error occurs in try block, will catch the errors in ** except** block
#
# - syntax errors will not catch

# %% [markdown]
# **divide by zero**

# %%
100/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 100/0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# **module not found**

# %%
import naga
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import naga
#
# ModuleNotFoundError: No module named 'naga'

# %% [markdown]
# **name error**

# %%
sachin
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 sachin
#
# NameError: name 'sachin' is not defined

# %% [markdown]
# **type error**

# %%
10+"sachin"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 10+"sachin"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 import random
# ----> 2 random.randint(1)
#
# TypeError: Random.randint() missing 1 required positional argument: 'b'

# %%
- value error
- type error
- name error
- zero division error
- modul not found 
- attribute error
- file exit error

# %%
try:
    <original code>
except Exception as e:
    print(e)

# %%
try:
    # if in this get error this full block not executed ---> jump to except block
except Exception as e:
    print(e)
    # in this block catch the error and print error and write code for exception handling

# %%
try:
    int("10.5")
except Exception as e:
    print(e)
# Out:
# invalid literal for int() with base 10: '10.5'

# %%
try:
    ans=int(10.5)
    print(ans)
except Exception as e:
    print(e)
# Out:
# 10

# %%
try:
    int("10.5")
except Exception as e:
    print(e)
    print(100+200)
# Out:
# invalid literal for int() with base 10: '10.5'
# 300

# %%
try:
    print("hi")
    print("hello")
    int("10.5")
    print("good")
except Exception as e:
    print(e)
    print("you write a wrong")

# %%
try:
    print(x)
except Exception as e:
    print(e)
# Out:
# name 'sachin' is not defined

# %%
try:
    sachin
    print("hi")
except Exception as e:
    print(e)
# Out:
# name 'sachin' is not defined

# %%
try:
    print(100/0)
except Exception as e:
    print(e)
# Out:
# division by zero

# %%
try:
    import naga
except Exception as e:
    print(e)
# Out:
# No module named 'naga'

# %%
import random
try:
   random.naga
except Exception as e:
    print(e)
# Out:
# module 'random' has no attribute 'naga'

# %%
try:
    import os 
    os.makedirs("virat")
except Exception as e:
    print(e)
# Out:
# [WinError 183] Cannot create a file when that file already exists: 'virat'

# %%
try:
    100+"sachin"
except Exception as e:
    print(e)
# Out:
# unsupported operand type(s) for +: 'int' and 'str'

# %%
try: 
    x=int("sachin")
except Exception as e:
    print(e)
# Out:
# invalid literal for int() with base 10: 'sachin'

# %%
# wap ask the user salary
    # ask the user enter tax_per
    # cal ho much tax we ned to pay
try:
    salary=eval(input("enter the salary:"))
    tax_per=eval(input("enter the tax_per: "))
    tax= salary*tax_per/100
    print(f"the total tax is : {tax}")
except Exception as e:
    print(e)
# Out:
# enter the salary: 500000000000
# enter the tax_per:  90
# the total tax is : 450000000000.0

# %%
try:
    num=int(input("enter a number:"))
    if num % 2 == 0:
        print(f"{num} is a even")
    else:
        print(f"{num} is a odd")
except Exception as e:
    print(e)
# Out:
# enter a number: -5
# odd

# %% [markdown]
# **try-except-finally**
#
# - originally code in **try** block
#
# - error catch in **except** block
#
# - **finally** block will activate either or try and except activate
#
# - assume that try block exceuted then finally block can also exceute
#
# - assume that except block exceuted then also finally block exceute
#
# coffee wll === try
# clean the kitchen  == finally
#
# cofee gone == except clean the kitchen === finally

# %%
try:
    print("connection established")
except Excepton as e:
    print(e)
finally:
    print("connecton closed")
# Out:
# connection established
# connecton closed
