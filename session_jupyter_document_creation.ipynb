# %%
Hello today iam learning python 
It is very interesting 
It is very easy 
I will attend class everyday

# %%
#shortcuts
esc+m ===> code to markdown mode
esc+y  ==> markdwon to code mode
shitf+enter  ===> run code
# {text} -->
esc+m --> shift+enter ===> biggest size text
##
###
####
#####
###### {python} ===> with 6 hash smallest text

# %% [markdown]
# # python

# %% [markdown]
# ## python

# %% [markdown]
# ### python

# %% [markdown]
# #### python

# %% [markdown]
# ##### python

# %% [markdown]
# ###### python

# %% [markdown]
# - in [ ] indicated cell in a code mode
# -  when [ ] are not there in cell is in markdown mode
# -  code mode is used to write codeing part
# -  markdown mode is used to the documentation of entire development like book

# %% [markdown]
# <img src="https://eu-images.contentstack.com/v3/assets/blt69509c9116440be8/bltdab34f69f74c72fe/65380fc40ef0e002921fc072/AI-thinking-Kittipong_Jirasukhanont-alamy.jpg" jsaction="" class="sFlh5c FyHeAf iPVvYb" style="max-width: 1700px; height: 203px; margin: 0px; width: 305px;" alt="Can AI Ever Become Capable of Original Thought?" jsname="kn3ccd">

# %% [markdown]
# <img src="https://sbscyber.com/hs-fs/hubfs/Images/BlogImages/AdobeStock_604631734.jpeg?width=8000&amp;height=4064&amp;name=AdobeStock_604631734.jpeg" jsaction="" class="sFlh5c FyHeAf iPVvYb" style="max-width: 8000px; height: 155px; margin: 0px; width: 305px;" alt="Risks and Benefits of AI for Businesses and Cybersecurity | SBS" jsname="kn3ccd">
