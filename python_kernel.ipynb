# %%
Python Kernel

- will you write python code : kernel will execute code
- kernel : computational engine 

-Kernel : white ==== idle state ===> ready to take work
        : black ==== busy state ===> already doing a work
        : red   ==== die state ===> kernel dead ====> restart the kernel

# %%
import time 
time.sleep(5)
print("hi")
# Out:
# hi

# %%
a=20 
print(a)
# Out:
# 20

# %% [markdown]
# - star mark indicates kernel is busy
# - do not run any cell

# %%
x = "123 "
for i in x: 
    print(i)
# Out:
# 1
# 2
# 3

# %%
Capt = False 
while True: 
    print(True) 
    break
# Out:
# True

# %%
for i in range(1, 100):   
    if i % 3 == 0: 
        break 
    print(i)

# %%
j = 1 
for i in range(1, 11):  # i from 1 to 10 inclusive 
    if i % 3 != 0: 
        j += 2 
    elif j % 3 == 0: 
        break 
print(i + j)
# Out:
# 15

# %%
x = 0 
for i in range(1, 6): 
    if i % 2 == 0: 
        x += i 
    else: 
        x -= i 
print(x)
# Out:
# -3
