# %%
n1=100

# %%
n2= 200

# %%
n1+n2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 n1+n2
#
# NameError: name 'n2' is not defined

# %%
#name error

# %%
name="python"

# %%
print(name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(name)
#
# NameError: name 'name' is not defined

# %%
a=10
b=20
c=30
b+d  # 20+d  name "d" not defined
d=50
a+d

# %%
NUMBER=100
NUMBER
# Out:
# 100

# %%
number=200
number
# Out:
# 200

# %%
NUMBER, number
# Out:
# (100, 200)

# %%
NUMBER, number
# Out:
# (100, 200)

# %%
NUMber=400
NUMber
# Out:
# 400

# %%
number123=600
number123
# Out:
# 600

# %%
num@ber=200
num@ber # special characters are not allowed

# %%
$number=100
# Out:
#   Cell In[10], line 1
#     $number=100
#     ^
# SyntaxError: invalid syntax

# %%
num_ber=200
num_ber
# Out:
# 200

# %%
num@ber=200  #error
$number=100  #error
num_ber=200  #work
areaofcircle=300 #work
area_of_circle=400  #work
area of circle=500  # error

# %%
_=500
_
# Out:
# 500

# %%
if = 500
if
# Out:
#   Cell In[14], line 1
#     if = 500
#        ^
# SyntaxError: invalid syntax

# %%
sum=500
sum
# Out:
# 500

# %%
print
sum is math family
max
min
len

# %%
l=[1,2,3,4]

# %%
print(l)
# Out:
# [1, 2, 3, 4]

# %%
type(l)
# Out:
# list

# %%
l=[1,2,3,4]
sum(l)
# Out:
# 10

# %%
max(l)
# Out:
# 4

# %%
min(l)
# Out:
# 1

# %%
len(l)
# Out:
# 4

# %% [markdown]
# - Variables can be capital and small letters
# - Variables are case sensitive
# - variables does not include special characters
# - number as prefix not allowed
# - variables can have underscores
# - only underscore also possible
# - reserved or keywoeds cna not be a variable
# - inbuilt function can not use as variable

# %%
a=100
b=200
c=300
(a+b+c)/3
# Out:
# 400.0

# %% [markdown]
# #python Assignment 1

# %%
#cluculet ara of circule
pi=3.14
r=10
area= pi*r*r
area
# Out:
# 314.0

# %%
# claculate total bill 
bill_amount=100
tip= 50

total_bill= bill_amount+ tip
total_bill
# Out:
# 150

# %%
#converted Kg to pound
weight_in_kg=60
weight_in_pound= weight_in_kg *2.2
weight_in_pound
# Out:
# 132.0

# %%
# converted dollars to rupee
dollars=10
indian_rupee= 80*dollars
indian_rupee
# Out:
# 800

# %%
#find area of rectangle
lenght=100
breadth=200
areaOfRectangle= lenght* breadth
areaOfRectangle
# Out:
# 20000
