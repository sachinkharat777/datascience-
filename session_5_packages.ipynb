# %% [markdown]
# **recap**
# - variables
# - data types
# - type casting
# - print statement
# - input and round
# - we perform the basic codes 3 ways
#   - using proper varible
#   - using print statement
#   - using input and round

# %% [markdown]
# # Packages and Modules

# %%
# Ramesh is a very googd student
# he created a python code which do the additon of two numbers
# Ramesh felt that this code no one created till now 
# Ramesh decided he wants to handover that to entire world
# He appraoched anaconda organization 
# my code should download automatically
# agreement
# additional.py file is available in my laptop

# %%
# import <module_name>
import addition
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import addition
#
# ModuleNotFoundError: No module named 'addition'

# %%
import random

# %%
import math

# %%
import time

# %%
import os

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
import virat
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import virat
#
# ModuleNotFoundError: No module named 'virat'

# %%
# Ramesh is so super exited
# he created subtraction, division, multiplication
# Anaconda is asking that handover that codes
# what are the ways ramesh
# Method-1:
    # addition.py
    # subtraction.py
    # multiplication.py
    # divition.py

# %% [markdown]
# **Module**
#
# - Module is a single python file
#
# - Having variables, functions, classes, methods
#
# **Package**
#
# - Package contains multiple python files
# - Assume that Ramesh has created 4 python files
#
#     - add.p
#     - sub.py
#     - mul.py
#     - div.py
#
# - All these 4 python files can save into a packge

# %%
math_function/
    add.py
    sub.py
    mul.py
    div.py

from math_functions import add
from math_functions import sub
from math_functions import mul
from math_functions import div

from math_function import add,sub,mul,div

# %% [markdown]
# - every python file ca be consider as module
# - every module has
#     - variables
#     - function
#         - some times we write these funtion under the **class**
#         - if a function is writing under the class we called as **method**
#
# - def fun1() ====> we called this fun1 is **function**.
# - if functio is under the class
#         - class
#         - def fun1() =====> then this is called **method**

# %% [markdown]
# **Random**

# %%
# step-1: import <module name>
# step-2: dir(<module name>)
# step-3: module_name.method_name
 # when we do step-3 some times
    #we will get answer
    # we will a get answer
      #  bound method or function

# %%
import random
dir (random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  '_warn',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
# ...

# %%
import time
dir(time)
# Out:
# ['_STRUCT_TM_ITEMS',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'altzone',
#  'asctime',
#  'ctime',
#  'daylight',
#  'get_clock_info',
#  'gmtime',
#  'localtime',
#  'mktime',
#  'monotonic',
#  'monotonic_ns',
#  'perf_counter',
#  'perf_counter_ns',
#  'process_time',
#  'process_time_ns',
#  'sleep',
#  'strftime',
#  'strptime',
#  'struct_time',
#  'thread_time',
#  'thread_time_ns',
#  'time',
#  'time_ns',
#  'timezone',
#  'tzname']

# %%
import math
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
import os
dir(os)
# Out:
# ['DirEntry',
#  'EX_OK',
#  'F_OK',
#  'GenericAlias',
#  'Mapping',
#  'MutableMapping',
#  'O_APPEND',
#  'O_BINARY',
#  'O_CREAT',
#  'O_EXCL',
#  'O_NOINHERIT',
#  'O_RANDOM',
#  'O_RDONLY',
#  'O_RDWR',
#  'O_SEQUENTIAL',
#  'O_SHORT_LIVED',
#  'O_TEMPORARY',
#  'O_TEXT',
#  'O_TRUNC',
#  'O_WRONLY',
#  'P_DETACH',
#  'P_NOWAIT',
#  'P_NOWAITO',
#  'P_OVERLAY',
#  'P_WAIT',
#  'PathLike',
#  'R_OK',
#  'SEEK_CUR',
#  'SEEK_END',
#  'SEEK_SET',
#  'TMP_MAX',
#  'W_OK',
#  'X_OK',
#  '_AddedDllDirectory',
#  '_Environ',
#  '__all__',
#  '__builtins__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_check_methods',
#  '_execvpe',
#  '_exists',
#  '_exit',
#  '_fspath',
#  '_get_exports_list',
#  '_walk_symlinks_as_files',
#  '_wrap_close',
#  'abc',
#  'abort',
#  'access',
#  'add_dll_directory',
#  'altsep',
#  'chdir',
#  'chmod',
#  'close',
#  'closerange',
#  'cpu_count',
#  'curdir',
#  'defpath',
#  'device_encoding',
# ...

# %% [markdown]
# **methods under a module also called as attributes**
#
# - random is module
#     - randint is a method or attribute
#
#     - random is a method or attribute
#
# - Every method purpose is different the use is different
#
# - if we wnat to call method or attribute, we need to call using module

# %%
import random
random.randint
# attribute randint available
# i missed the brackets then bound method is coming
# Out:
# <bound method Random.randint of <random.Random object at 0x00000253638144F0>>

# %%
import random
random.randintt
# attribute randint available
# i missed the spelling then bound method is coming
#AttributeError: module 'random' has no attribute 'randintt'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 2
#       1 import random
# ----> 2 random.randintt
#
# AttributeError: module 'random' has no attribute 'randintt'

# %%
import random
random.virat
# no attribute name virat
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 2
#       1 import random
# ----> 2 random.virat
#
# AttributeError: module 'random' has no attribute 'virat'

# %%
# step-1: import <module name>
# step-2: dir(<module name>)
# step-3: module_name.method_name
 # when we do step-3 some times
    #we will get answer
    # we will a get answer
      #  bound method or function

# %%
import random
#dir(random)
random.randint
# Out:
# <bound method Random.randint of <random.Random object at 0x00000253638144F0>>

# %%
# what is the works randint will do?
help(random.randint)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.

# %%
random.randint(1,10)
# Out:
# 7

# %%
# step-1: import modulename
# step-2: dir(moduleName)
# step-3: moduname.methodname
# step-4: help(modulename.methodname)
# step-5: apply the use case

# %%
import random
dir(random)
help(random.randint)
random.randint(1,10)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.
# 2

# %%
import random
dir(random)
help(random.random)
random.random()
# Out:
# Help on built-in function random:
#
# random() method of random.Random instance
#     random() -> x in the interval [0, 1).
# 0.021216778942026893

# %%
import random

# %%
# module     method
# random        randint
# random        random
# random        choice
# random        shufffle
# math           e
# math          pi
# math          sqrt
# math          pow
# math          sin
# math          ceill
# time          sleep
# os            getcwd
# os            listdir

l=[10,20,30,40]
random.choice(l)    # take your cursor inside the brackets and apply  shift+tab

#firtst import random
#then next cell the shfit + tab
# Out:
# 20

# %%
random.randint(1,10)
# Out:
# 10

# %%
x=[1,2,3,4]
random.shuffle(x)
# help(random.shuffle)
x
# Out:
# [4, 1, 3, 2]

# %%
random.random()
# help(random.random)
# Out:
# 0.4372058821103645

# %%
import math

# %%
math.e()
# math.e
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 math.e()
#
# TypeError: 'float' object is not callable

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.sqrt(16) #  Return the square root of x
# Out:
# 4.0

# %%
math.pow(2,3)  #Return x**y (x to the power of y).
# Out:
# 8.0

# %%
math.sin(10) # Return the sine of x (measured in radians)
# Out:
# -0.5440211108893698

# %%
math.ceil(40.678) # Return the ceiling of x as an Integral. This is the smallest integer >= x.
# Out:
# 41

# %%
math.ceil(40.1234)
# Out:
# 41

# %%
import time

# %%
start=time.time() # random value
time.sleep(5)
print("hi")
end=time.time() # random value
end-start
# Out:
# hi
# 5.00075626373291

# %%
start=time.time()
print("good env")
end=time.time()
end-start
# Out:
# good env
# 0.000997304916381836

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\sachi\\OneDrive\\Documents\\NareshIT\\Python_sessions'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'data_type_practice_qns.ipynb',
#  'python_Assignment_all',
#  'python_kernel.ipynb',
#  'python_session2.ipynb',
#  'sessions_1_variables.ipynb',
#  'sessions_2_data_types.ipynb',
#  'session_3_print_statement.ipynb',
#  'session_4_input_eval_statement.ipynb',
#  'session_5_packages.ipynb',
#  'session_jupyter_document_creation.ipynb',
#  'Untitled.ipynb',
#  'workshop_2_genai.ipynb']

# %%
os.makedirs("sachin")

# %%
os.makedirs("mahi7")

# %%
# module  :  keyword
# method  :  kwlist

# %%
import keyword

# %%
dir(keyword)
# Out:
# ['__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'iskeyword',
#  'issoftkeyword',
#  'kwlist',
#  'softkwlist']

# %%
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
1. we understood the modules and packages
2. we understood the difference between
	function and methods
3. import <module_name>
4. dir()

# %%
# upper case
# lower case
# punctuation
#digit

# %%
import string

# %%
dir(string)
# Out:
# ['Formatter',
#  'Template',
#  '_ChainMap',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_re',
#  '_sentinel_dict',
#  '_string',
#  'ascii_letters',
#  'ascii_lowercase',
#  'ascii_uppercase',
#  'capwords',
#  'digits',
#  'hexdigits',
#  'octdigits',
#  'printable',
#  'punctuation',
#  'whitespace']

# %%
string.ascii_uppercase
# Out:
# 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
string.ascii_lowercase
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
string.whitespace
# Out:
# ' \t\n\r\x0b\x0c'

# %%
import random
random.randint(10,20)
# Out:
# 13

# %%
from random import randint
randint(10,20)
# Out:
# 11

# %%
import random
random
# Out:
# <module 'random' from 'C:\\Users\\sachi\\anaconda3\\Lib\\random.py'>

# %%
import flask

# %%
import streamlit

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
import langchain
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 import langchain
#
# ModuleNotFoundError: No module named 'langchain'

# %%
pip install langchain
# Out:
# ...
#      ---------------------------------------- 0.0/42.9 kB ? eta -:--:--
#      ---------------------------------------- 42.9/42.9 kB 1.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/93.7 kB ? eta -:--:--
#    ---------------------------------------  92.2/93.7 kB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 93.7/93.7 kB 1.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/471.5 kB ? eta -:--:--
#    ------ --------------------------------- 71.7/471.5 kB 1.3 MB/s eta 0:00:01
#    ------------- -------------------------- 153.6/471.5 kB 1.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 204.8/471.5 kB 1.6 MB/s eta 0:00:01
#    --------------------- ------------------ 256.0/471.5 kB 1.3 MB/s eta 0:00:01
#    -------------------------- ------------- 307.2/471.5 kB 1.4 MB/s eta 0:00:01
#    ------------------------------- -------- 368.6/471.5 kB 1.3 MB/s eta 0:00:01
# ...

# %%
import virat
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import virat
#
# ModuleNotFoundError: No module named 'virat'

# %%
pip install langchain
# Out:
# ...
#
# ...

# %%
import langchain

# %%
import cv2

# %%
import langgraph

# %%
import tensorflow
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import tensorflow
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
pip freeze
# Out:
# aext-assistant @ file:///C:/miniconda3/conda-bld/aext-assistant_1761258983816/work
# aext-assistant-server @ file:///C:/miniconda3/conda-bld/aext-assistant-server_1761255138803/work
# aext-core @ file:///C:/miniconda3/conda-bld/aext-core_1761258466612/work
# aext-core-server @ file:///C:/miniconda3/conda-bld/aext-core-server_1761254547721/work
# aext-notebook-load-server @ file:///C:/miniconda3/conda-bld/aext-notebook-load-server_1761255340302/work/backend_lib/notebook_load
# aext-panels @ file:///C:/miniconda3/conda-bld/aext-panels_1761258495739/work
# aext-panels-server @ file:///C:/miniconda3/conda-bld/aext-panels-server_1761255224811/work
# aext-project-filebrowser-server @ file:///C:/miniconda3/conda-bld/aext-project-filebrowser-server_1761260433133/work/backend_lib/project_filebrowser
# aext-share-notebook-server @ file:///C:/miniconda3/conda-bld/aext-share-notebook-server_1761255322704/work
# aext-shared @ file:///C:/miniconda3/conda-bld/aext-shared_1761252342981/work
# ...

# %%
import tensorflow

# %%
import tensorflow as tf

# %%
import numpy as np
